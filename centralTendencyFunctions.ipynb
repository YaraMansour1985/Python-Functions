# %% [markdown]
# <a href="https://colab.research.google.com/github/YaraMansour1985/Python-Functions/blob/main/centralTendencyFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
week_1=[45,55,49,60,52,55,58]
week_2=[51,49,62,50,53,56,59]
week_3=[60,61,61,62,57,59,58]
week_4=[59,63,62,61,65,66,62]

import numpy as np
np.mean(week_1)

np.float64(53.42857142857143)

import numpy as np
np.median(week_1)

np.float64(55.0)

from statistics import mode
mode(week_1)

55

def central_tendency(temps):
    mean_val=np.mean(temps)
    median_val=np.median(temps)
    from statistics import mode
    mode_val=mode(temps)
    return (mean_val,median_val,mode_val)

week1_results=central_tendency(week_1)
print(week1_results)
week2_results=central_tendency(week_2)
print(week2_results)

(np.float64(53.42857142857143), np.float64(55.0), 55)
(np.float64(54.285714285714285), np.float64(53.0), 51)

def central_tendency(temps, verbose=True):
    mean_val=np.mean(temps)
    median_val=np.median(temps)
    from statistics import mode
    mode_val=mode(temps)
    if verbose==True:
        print('Mean:',mean_val,'Median:',median_val,'Mode:',mode_val)
    return (mean_val,median_val,mode_val)

week_2=[51,49,62,50,53,56,59]
print("with verbose=True")
central_tendency(week_2,verbose=True)
print("with verbose=False")
central_tendency(week_2,verbose=False)
# Out:
# (np.float64(53.42857142857143), np.float64(55.0), 55)
# (np.float64(54.285714285714285), np.float64(53.0), 51)
# with verbose=True
# Mean: 54.285714285714285 Median: 53.0 Mode: 51
# with verbose=False
# (np.float64(54.285714285714285), np.float64(53.0), 51)

# %%
Variables and Primitive Data Types Practice

Task 0

Print the string 'Hello World!'

    # print ("Hello World!")

Task 1a

Define a variable distance that points to 140.

Define a variable time that points to 3.

Define a variable speed that points to the calculation for the speed. Be
sure to use the variables names in your calculation. (Speed =
distance/time)

Print the speed using print(speed)

    distance=140
    time=3
    speed=(distance/time)
    #print(speed)

#Task 1b Build on your previous code.

Instead of just printing speed, print an f statement that says:

If it takes __ hours to travel __ miles, the speed is __ miles per hour.

Fill in the blanks with the appropriate variables.

    # print(f "If it takes  {time} hours to travel {distance} miles , the speed is {speed}miles per hour.")

Task 1c

Check the data type of all three of your variables

    (type(distance))

     (type(time))

    (type(speed))

Task 1d

Change the data type of time from integer to float.

Recheck the data type to confirm it is a float.

    time=float(time)
    type(time)

Task 2a

Define a variable customer that points to a string with the customer's
name, Charlene.

Print the customer's name using print(customer)

    customer_name=("Charlene")
    # print (customer_name)

Task 2b

Check the data type of customer

    # type(customer_name)

Task 2c

Set up a comparison statement using == to test if the customer is
Charlene.

Your code should return True.

    # your code here
    # type( customer_name=="Charlene")

Task 2d

Set up a compararison statement using == to test if the customer is Bob.

Your code should return False.

    # your code here
    #type (customer_name=="Bob")
